# %%
pip install imblearn

# %%
import pandas as pd
from imblearn.over_sampling import RandomOverSampler

# %%
df = pd.
# Out:
# Index(['text', 'label', 'text_clean_tfidf', 'text_clean_bert'], dtype='object')
