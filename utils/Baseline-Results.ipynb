# %%
import matplotlib.pyplot as plt
import pandas as pd

# Example results (replace with your actual numbers)
results = {
    "Dataset": ["REAL/FAKE", "WELFake", "LIAR", "FEVER", "Indian", "Merged"],
    "LogReg": [0.94, 0.93, 0.92, 0.91, 0.95, 0.62],
    "SVM":    [0.95, 0.94, 0.91, 0.90, 0.94, 0.61],
    "MultNB": [0.92, 0.90, 0.89, 0.88, 0.93, 0.59],
    "CompNB": [0.93, 0.91, 0.90, 0.89, 0.94, 0.60],
    "RF":     [0.90, 0.89, 0.88, 0.87, 0.91, 0.58],
    "Boost":  [0.91, 0.90, 0.89, 0.87, 0.92, 0.60],
}

df = pd.DataFrame(results)

# Plot
plt.figure(figsize=(12,6))
for model in df.columns[1:]:
    plt.plot(df["Dataset"], df[model], marker="o", label=model)

plt.title("Baseline Model Accuracy Across Datasets", fontsize=14)
plt.xlabel("Dataset", fontsize=12)
plt.ylabel("Accuracy", fontsize=12)
plt.ylim(0.5, 1.0)
plt.legend()
plt.grid(alpha=0.3)
plt.show()
